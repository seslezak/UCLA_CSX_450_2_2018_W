# %%
titanic <- read.table('train.csv', sep=",", header = T)

# %%
rownames(titanic) <- titanic$PassengerId
titanic$PassengerId <- NULL
titanic$Name <- NULL

# %%
names(titanic)
titanic
# Out:
#  [1] "Survived" "Pclass"   "Sex"      "Age"      "SibSp"    "Parch"
#  [7] "Ticket"   "Fare"     "Cabin"    "Embarked"
#     Survived Pclass Sex    Age SibSp Parch Ticket           Fare
# 1   0        3      male   22  1     0     A/5 21171          7.2500
# 2   1        1      female 38  1     0     PC 17599          71.2833
# 3   1        3      female 26  0     0     STON/O2. 3101282   7.9250
# 4   1        1      female 35  1     0     113803            53.1000
# 5   0        3      male   35  0     0     373450             8.0500
# 6   0        3      male   NA  0     0     330877             8.4583
# 7   0        1      male   54  0     0     17463             51.8625
# 8   0        3      male    2  3     1     349909            21.0750
# 9   1        3      female 27  0     2     347742            11.1333
# 10  1        2      female 14  1     0     237736            30.0708
# 11  1        3      female  4  1     1     PP 9549           16.7000
# 12  1        1      female 58  0     0     113783            26.5500
# 13  0        3      male   20  0     0     A/5. 2151          8.0500
# 14  0        3      male   39  1     5     347082            31.2750
# 15  0        3      female 14  0     0     350406             7.8542
# 16  1        2      female 55  0     0     248706            16.0000
# 17  0        3      male    2  4     1     382652            29.1250
# 18  1        2      male   NA  0     0     244373            13.0000
# 19  0        3      female 31  1     0     345763            18.0000
# 20  1        3      female NA  0     0     2649               7.2250
# 21  0        2      male   35  0     0     239865            26.0000
# 22  1        2      male   34  0     0     248698            13.0000
# 23  1        3      female 15  0     0     330923             8.0292
# 24  1        1      male   28  0     0     113788            35.5000
# 25  0        3      female  8  3     1     349909            21.0750
# 26  1        3      female 38  1     5     347077            31.3875
# 27  0        3      male   NA  0     0     2631               7.2250
# 28  0        1      male   19  3     2     19950            263.0000
# 29  1        3      female NA  0     0     330959             7.8792
# 30  0        3      male   NA  0     0     349216             7.8958
# ⋮   ⋮        ⋮      ⋮      ⋮   ⋮     ⋮     ⋮                ⋮
# 862 0        2      male   21  1     0     28134            11.5000
# 863 1        1      female 48  0     0     17466            25.9292
# 864 0        3      female NA  8     2     CA. 2343         69.5500
# 865 0        2      male   24  0     0     233866           13.0000
# 866 1        2      female 42  0     0     236852           13.0000
# 867 1        2      female 27  1     0     SC/PARIS 2149    13.8583
# 868 0        1      male   31  0     0     PC 17590         50.4958
# 869 0        3      male   NA  0     0     345777            9.5000
# 870 1        3      male    4  1     1     347742           11.1333
# 871 0        3      male   26  0     0     349248            7.8958
# 872 1        1      female 47  1     1     11751            52.5542
# 873 0        1      male   33  0     0     695               5.0000
# 874 0        3      male   47  0     0     345765            9.0000
# 875 1        2      female 28  1     0     P/PP 3381        24.0000
# 876 1        3      female 15  0     0     2667              7.2250
# 877 0        3      male   20  0     0     7534              9.8458
# 878 0        3      male   19  0     0     349212            7.8958
# 879 0        3      male   NA  0     0     349217            7.8958
# 880 1        1      female 56  0     1     11767            83.1583
# 881 1        2      female 25  0     1     230433           26.0000
# 882 0        3      male   33  0     0     349257            7.8958
# 883 0        3      female 22  0     0     7552             10.5167
# 884 0        2      male   28  0     0     C.A./SOTON 34068 10.5000
# 885 0        3      male   25  0     0     SOTON/OQ 392076   7.0500
# 886 0        3      female 39  0     5     382652           29.1250
# 887 0        2      male   27  0     0     211536           13.0000
# 888 1        1      female 19  0     0     112053           30.0000
# 889 0        3      female NA  1     2     W./C. 6607       23.4500
# 890 1        1      male   26  0     0     111369           30.0000
# 891 0        3      male   32  0     0     370376            7.7500
#     Cabin       Embarked
# 1               S
# 2   C85         C
# 3               S
# 4   C123        S
# 5               S
# 6               Q
# 7   E46         S
# 8               S
# 9               S
# 10              C
# 11  G6          S
# 12  C103        S
# 13              S
# 14              S
# 15              S
# 16              S
# 17              Q
# 18              S
# 19              S
# 20              C
# 21              S
# 22  D56         S
# 23              Q
# 24  A6          S
# 25              S
# 26              S
# 27              C
# 28  C23 C25 C27 S
# 29              Q
# 30              S
# ⋮   ⋮           ⋮
# 862             S
# 863 D17         S
# 864             S
# 865             S
# 866             S
# 867             C
# 868 A24         S
# 869             S
# 870             S
# 871             S
# 872 D35         S
# 873 B51 B53 B55 S
# 874             S
# 875             C
# 876             C
# 877             S
# 878             S
# 879             S
# 880 C50         C
# 881             S
# 882             S
# 883             S
# 884             S
# 885             S
# 886             Q
# 887             S
# 888 B42         S
# 889             S
# 890 C148        C
# 891             Q

# %%
str(titanic)
# Out:
# 'data.frame':	891 obs. of  10 variables:
#  $ Survived: int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Pclass  : int  3 1 3 1 3 3 1 3 3 2 ...
#  $ Sex     : Factor w/ 2 levels "female","male": 2 1 1 1 2 2 2 2 1 1 ...
#  $ Age     : num  22 38 26 35 35 NA 54 2 27 14 ...
#  $ SibSp   : int  1 1 0 1 0 0 0 3 0 1 ...
#  $ Parch   : int  0 0 0 0 0 0 0 1 2 0 ...
#  $ Ticket  : Factor w/ 681 levels "110152","110413",..: 524 597 670 50 473 276 86 396 345 133 ...
#  $ Fare    : num  7.25 71.28 7.92 53.1 8.05 ...
#  $ Cabin   : Factor w/ 148 levels "","A10","A14",..: 1 83 1 57 1 1 131 1 1 1 ...
#  $ Embarked: Factor w/ 4 levels "","C","Q","S": 4 2 4 4 4 3 4 4 4 2 ...

# %%
titanic$Sex <- as.integer(titanic$Sex == 'female')
titanic
# Out:
#     Survived Pclass Sex Age SibSp Parch Ticket           Fare     Cabin
# 1   0        3      0   22  1     0     A/5 21171          7.2500
# 2   1        1      1   38  1     0     PC 17599          71.2833 C85
# 3   1        3      1   26  0     0     STON/O2. 3101282   7.9250
# 4   1        1      1   35  1     0     113803            53.1000 C123
# 5   0        3      0   35  0     0     373450             8.0500
# 6   0        3      0   NA  0     0     330877             8.4583
# 7   0        1      0   54  0     0     17463             51.8625 E46
# 8   0        3      0    2  3     1     349909            21.0750
# 9   1        3      1   27  0     2     347742            11.1333
# 10  1        2      1   14  1     0     237736            30.0708
# 11  1        3      1    4  1     1     PP 9549           16.7000 G6
# 12  1        1      1   58  0     0     113783            26.5500 C103
# 13  0        3      0   20  0     0     A/5. 2151          8.0500
# 14  0        3      0   39  1     5     347082            31.2750
# 15  0        3      1   14  0     0     350406             7.8542
# 16  1        2      1   55  0     0     248706            16.0000
# 17  0        3      0    2  4     1     382652            29.1250
# 18  1        2      0   NA  0     0     244373            13.0000
# 19  0        3      1   31  1     0     345763            18.0000
# 20  1        3      1   NA  0     0     2649               7.2250
# 21  0        2      0   35  0     0     239865            26.0000
# 22  1        2      0   34  0     0     248698            13.0000 D56
# 23  1        3      1   15  0     0     330923             8.0292
# 24  1        1      0   28  0     0     113788            35.5000 A6
# 25  0        3      1    8  3     1     349909            21.0750
# 26  1        3      1   38  1     5     347077            31.3875
# 27  0        3      0   NA  0     0     2631               7.2250
# 28  0        1      0   19  3     2     19950            263.0000 C23 C25 C27
# 29  1        3      1   NA  0     0     330959             7.8792
# 30  0        3      0   NA  0     0     349216             7.8958
# ⋮   ⋮        ⋮      ⋮   ⋮   ⋮     ⋮     ⋮                ⋮        ⋮
# 862 0        2      0   21  1     0     28134            11.5000
# 863 1        1      1   48  0     0     17466            25.9292  D17
# 864 0        3      1   NA  8     2     CA. 2343         69.5500
# 865 0        2      0   24  0     0     233866           13.0000
# 866 1        2      1   42  0     0     236852           13.0000
# 867 1        2      1   27  1     0     SC/PARIS 2149    13.8583
# 868 0        1      0   31  0     0     PC 17590         50.4958  A24
# 869 0        3      0   NA  0     0     345777            9.5000
# 870 1        3      0    4  1     1     347742           11.1333
# 871 0        3      0   26  0     0     349248            7.8958
# 872 1        1      1   47  1     1     11751            52.5542  D35
# 873 0        1      0   33  0     0     695               5.0000  B51 B53 B55
# 874 0        3      0   47  0     0     345765            9.0000
# 875 1        2      1   28  1     0     P/PP 3381        24.0000
# 876 1        3      1   15  0     0     2667              7.2250
# 877 0        3      0   20  0     0     7534              9.8458
# 878 0        3      0   19  0     0     349212            7.8958
# 879 0        3      0   NA  0     0     349217            7.8958
# 880 1        1      1   56  0     1     11767            83.1583  C50
# 881 1        2      1   25  0     1     230433           26.0000
# 882 0        3      0   33  0     0     349257            7.8958
# 883 0        3      1   22  0     0     7552             10.5167
# 884 0        2      0   28  0     0     C.A./SOTON 34068 10.5000
# 885 0        3      0   25  0     0     SOTON/OQ 392076   7.0500
# 886 0        3      1   39  0     5     382652           29.1250
# 887 0        2      0   27  0     0     211536           13.0000
# 888 1        1      1   19  0     0     112053           30.0000  B42
# 889 0        3      1   NA  1     2     W./C. 6607       23.4500
# 890 1        1      0   26  0     0     111369           30.0000  C148
# 891 0        3      0   32  0     0     370376            7.7500
#     Embarked
# 1   S
# 2   C
# 3   S
# 4   S
# 5   S
# 6   Q
# 7   S
# 8   S
# 9   S
# 10  C
# 11  S
# 12  S
# 13  S
# 14  S
# 15  S
# 16  S
# 17  Q
# 18  S
# 19  S
# 20  C
# 21  S
# 22  S
# 23  Q
# 24  S
# 25  S
# 26  S
# 27  C
# 28  S
# 29  Q
# 30  S
# ⋮   ⋮
# 862 S
# 863 S
# 864 S
# 865 S
# 866 S
# 867 C
# 868 S
# 869 S
# 870 S
# 871 S
# 872 S
# 873 S
# 874 S
# 875 C
# 876 C
# 877 S
# 878 S
# 879 S
# 880 C
# 881 S
# 882 S
# 883 S
# 884 S
# 885 S
# 886 Q
# 887 S
# 888 S
# 889 S
# 890 C
# 891 Q

# %%
titanic$Pclass <- factor(titanic$Pclass)
titanic$Embarked <- factor(titanic$Embarked)
str(titanic)
# Out:
# 'data.frame':	891 obs. of  10 variables:
#  $ Survived: int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Pclass  : Factor w/ 3 levels "1","2","3": 3 1 3 1 3 3 1 3 3 2 ...
#  $ Sex     : int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Age     : num  22 38 26 35 35 NA 54 2 27 14 ...
#  $ SibSp   : int  1 1 0 1 0 0 0 3 0 1 ...
#  $ Parch   : int  0 0 0 0 0 0 0 1 2 0 ...
#  $ Ticket  : Factor w/ 681 levels "110152","110413",..: 524 597 670 50 473 276 86 396 345 133 ...
#  $ Fare    : num  7.25 71.28 7.92 53.1 8.05 ...
#  $ Cabin   : Factor w/ 148 levels "","A10","A14",..: 1 83 1 57 1 1 131 1 1 1 ...
#  $ Embarked: Factor w/ 4 levels "","C","Q","S": 4 2 4 4 4 3 4 4 4 2 ...

# %%
titanic$Ticket <- NULL
titanic$Cabin <- NULL
str(titanic)
# Out:
# 'data.frame':	891 obs. of  8 variables:
#  $ Survived: int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Pclass  : Factor w/ 3 levels "1","2","3": 3 1 3 1 3 3 1 3 3 2 ...
#  $ Sex     : int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Age     : num  22 38 26 35 35 NA 54 2 27 14 ...
#  $ SibSp   : int  1 1 0 1 0 0 0 3 0 1 ...
#  $ Parch   : int  0 0 0 0 0 0 0 1 2 0 ...
#  $ Fare    : num  7.25 71.28 7.92 53.1 8.05 ...
#  $ Embarked: Factor w/ 4 levels "","C","Q","S": 4 2 4 4 4 3 4 4 4 2 ...

# %%
str(titanic)
# Out:
# 'data.frame':	891 obs. of  8 variables:
#  $ Survived: int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Pclass  : Factor w/ 3 levels "1","2","3": 3 1 3 1 3 3 1 3 3 2 ...
#  $ Sex     : int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Age     : num  22 38 26 35 35 NA 54 2 27 14 ...
#  $ SibSp   : int  1 1 0 1 0 0 0 3 0 1 ...
#  $ Parch   : int  0 0 0 0 0 0 0 1 2 0 ...
#  $ Fare    : num  7.25 71.28 7.92 53.1 8.05 ...
#  $ Embarked: Factor w/ 4 levels "","C","Q","S": 4 2 4 4 4 3 4 4 4 2 ...

# %%
colSums(is.na(titanic))
# Out:
# Survived   Pclass      Sex      Age    SibSp    Parch     Fare Embarked
#        0        0        0      177        0        0        0        0

# %%
attach(titanic)

# %%
library(repr); options(repr.plot.width=10, repr.plot.height=3)
par(mfrow = c(1,6))
hist(Survived)
hist(Sex)
hist(Age)
hist(SibSp)
hist(Parch)
hist(Fare)
# Out:
# Plot with title “Histogram of Fare”

# %%
options(repr.plot.width=10, repr.plot.height=3)
library(MASS)
par(mfrow = c(1,6))
truehist(Survived, h = 1)
truehist(Sex, h = 1)
truehist(Age, h = 5)
truehist(SibSp)
truehist(Parch)
truehist(Fare)
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=6)
pairs(titanic)
# Out:
# plot without title

# %%
titanic_numeric_features <- Filter(is.numeric, titanic)

# %%
options(repr.plot.width=10, repr.plot.height=6)
pairs(titanic_numeric_features)
# Out:
# plot without title

# %%
cor(titanic_numeric_features)
# Out:
#          Survived    Sex       Age SibSp      Parch      Fare
# Survived  1.00000000 0.5433514 NA  -0.0353225 0.08162941 0.2573065
# Sex       0.54335138 1.0000000 NA   0.1146308 0.24548896 0.1823328
# Age               NA        NA  1          NA         NA        NA
# SibSp    -0.03532250 0.1146308 NA   1.0000000 0.41483770 0.1596510
# Parch     0.08162941 0.2454890 NA   0.4148377 1.00000000 0.2162249
# Fare      0.25730652 0.1823328 NA   0.1596510 0.21622494 1.0000000

# %%
mean(titanic_numeric_features$Age, na.rm = T)

# %%
mean_age <- mean(titanic_numeric_features$Age, na.rm = T)
titanic_numeric_features$Age[is.na(titanic_numeric_features$Age)] <- mean_age

# %%
cor(titanic_numeric_features)
# Out:
#          Survived    Sex         Age         SibSp      Parch       Fare
# Survived  1.00000000  0.54335138 -0.06980852 -0.0353225  0.08162941 0.25730652
# Sex       0.54335138  1.00000000 -0.08415344  0.1146308  0.24548896 0.18233283
# Age      -0.06980852 -0.08415344  1.00000000 -0.2326246 -0.17919092 0.09156609
# SibSp    -0.03532250  0.11463081 -0.23262459  1.0000000  0.41483770 0.15965104
# Parch     0.08162941  0.24548896 -0.17919092  0.4148377  1.00000000 0.21622494
# Fare      0.25730652  0.18233283  0.09156609  0.1596510  0.21622494 1.00000000
